# %%
timeframe = "15"
strategy = "combinedStrategy"
config = "user_data/combined_config.json"

# %%
# !docker-compose run --rm ft2 download-data -t $timeframe -c $config
# !docker-compose run --rm ft2 backtesting -c $config -s $strategy
