# %%
timeframe = ['1m','5m','15m','30m','1h','1d']
strategy = ["combinedStrategy"]
config = "user_data/combined_config.json"
hyperopt_loss = ["SharpeHyperOptLoss"]
epoch = 1000

# %%
# !docker-compose run --rm ft2 download-data -t $timeframe[2] -c $config
# !docker-compose run --rm ft2 backtesting -c $config -s $strategy[0] --export trades
# !docker-compose run --rm ft2 hyperopt --enable-protections -c $config -s $strategy[0] --hyperopt-loss $hyperopt_loss[0] -e $epoch
