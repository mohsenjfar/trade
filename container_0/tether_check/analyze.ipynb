# %%
python3 -m ipykernel install --user --name myenv --display-name "Tether"

# %%
# !django-admin startproject analyze

# %%
# !python3 ./analyze/manage.py startapp tether

# %%
# !python3 ./analyze/manage.py makemigrations
# !python3 ./analyze/manage.py migrate

# %%
# !pip3 freeze > requirements.txt

# %%
import requests

# %%
bot_url = "https://api.telegram.org/bot6233446929%3AAAE9qKnXSiweUxFF_m4i57uNAO2WobOtSv0/sendMessage"
bot_headers = {
    "accept": "application/json",
    "content-type": "application/json"
}
payload = {
    "text": "Hi",
    "disable_web_page_preview": False,
    "disable_notification": False,
    "reply_to_message_id": None,
    "chat_id": "6233446929"
}
response = requests.post(bot_url, json=payload, headers=bot_headers)
print(response.text)
# Out:
# {"ok":false,"error_code":403,"description":"Forbidden: bot can't send messages to bots"}
