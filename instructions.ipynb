# %% [markdown]
# # Trading

# %% [markdown]
# ## Materials
# - [Elder Alexander - Trading For A Living.pdf](./docs/Elder%20Alexander%20-%20Trading%20For%20A%20Living.pdf)

# %% [markdown]
# # NFTs

# %% [markdown]
# ## SwissCheese

# %% [markdown]
# ## Ecoterra

# %% [markdown]
# # Wallets

# %% [markdown]
# ## Trustwallet

# %% [markdown]
# ## Metamask

# %% [markdown]
# # Exchanges

# %% [markdown]
# ## kucoin
#
# ### Mining pool
#
# #### Miners
#
# - Antminer
#   - [S19Pro](https://www.itbazar.com/p_70376.aspx)
#   - S19+
#   - S19
#   - T19
#   - S17+
#   - T17+
#   - S17
#
# - Avalon
#    - A1246
#    - A1166Pro
#    - A1166
#    - A1146
#
# - WhatsMiner
#    - [M30S++](https://www.itbazar.com/p_105639.aspx)
#    - [M30S+](https://www.itbazar.com/p_112319.aspx)
#    - M30S
#    - M31S+
#
# - Innosilicon
#   - T4+
#   - T3+Pro
#   - T3+
#   - T3
#   - [T2T](https://www.itbazar.com/p_77026.aspx)
#
# - Ebit
#   - E12+
#   - E12
#   - E11++
#   - E10

# %% [markdown]
# ## Nobitex

# %% [markdown]
# ## Abantether

# %% [markdown]
# ## Bingx

# %% [markdown]
# ## Bit24

# %% [markdown]
# # News and data

# %% [markdown]
# ## Coinmarketcap

# %% [markdown]
# ## Coindesk
